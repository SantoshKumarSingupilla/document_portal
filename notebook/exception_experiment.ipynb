# %%
pip install ipykernel

# %%
print("all ok")
# Out:
# all ok

# %%
### __file__ in .py file automatically gets the name of the file

# %%
from logger.custom_logger import CustomLogger
logger=CustomLogger().get_logger("exception_experiment")

# %%
import sys
import traceback # we can capture the detail regarding my execution
class DocumentPortalException(Exception): #we have inherited the exception class
    """Custom exception for Document Portal"""
    def __init__(self,error_message,error_details:sys): #denotes the type of the error details is sys
        print(error_details.exc_info()) 
        _,_,exc_tb=error_details.exc_info()
        #exe_info will provide the complete execution details
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info())) #will provide the complete traceback details
    def __str__(self):  #string representation of the object
       return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback:
        {self.traceback_str}
        """
    
if __name__ == "__main__":
    try:
        # Simulate an error
        a = 1 / 0
        print(a)
    except Exception as e:
        app_exc=DocumentPortalException(e,sys) #exception message, system module - will provide complete detail of the error
        logger.error(app_exc) #log the error
        raise app_exc #raise the exception
# Out:
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x0000021739AC2080>)
# {"timestamp": "2025-11-12T06:14:17.779228Z", "level": "error", "event": "DocumentPortalException(ZeroDivisionError('division by zero'), <module 'sys' (built-in)>)"}
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 24
#      22 try:
#      23     # Simulate an error
# ---> 24     a = 1 / 0
#      25     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[7], line 29
#      27 app_exc=DocumentPortalException(e,sys) #exception message, system module - will provide complete detail of the error
#      28 logger.error(app_exc) #log the error
# ---> 29 raise app_exc #raise the exception
#
# ...

# %%
1. log this error(file, cloud config, command prompt) (it will keep the record of the error and will not stop the execution of the code)
2. raise the exception(it will stop the execution of the code)

# %%
(<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x00000231341AAD40>)

# %%
import sys
sys.exc_info()
# Out:
# (None, None, None)

# %%
a,b,c=(1,2,3)

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3
